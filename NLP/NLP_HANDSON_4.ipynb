# %%
#2. SIMPLE TEXT CLASSIFICATION 
def gender_features(word):
    return{'last_letter': word[-1]}

# %%
gender_features('Obama')
# Out:
# {'last_letter': 'a'}

# %%
from nltk.corpus import names

# %%
#names.words()
#print(len(names.words()))
labeled_names = ([(name,'male') for name in names.words('male.txt')]+[(name,'female') for name in names.words('female.txt')])
import random
random.shuffle(labeled_names)
labeled_names
# Out:
# [('Lauretta', 'female'),
#  ('Shara', 'female'),
#  ('Pammy', 'female'),
#  ('Jean-Lou', 'male'),
#  ('Paulo', 'male'),
#  ('Sarge', 'male'),
#  ('Alana', 'female'),
#  ('Nananne', 'female'),
#  ('Merrielle', 'female'),
#  ('Dorthea', 'female'),
#  ('Maddalena', 'female'),
#  ('Rebekah', 'female'),
#  ('Tommy', 'female'),
#  ('Nicolas', 'male'),
#  ('Sandy', 'female'),
#  ('Caspar', 'male'),
#  ('Jennifer', 'female'),
#  ('Gerry', 'female'),
#  ('Dede', 'female'),
#  ('Batsheva', 'female'),
#  ('Marlo', 'female'),
#  ('Eveline', 'female'),
#  ('Rosabel', 'female'),
#  ('Hannibal', 'female'),
#  ('Auberta', 'female'),
#  ('Malcah', 'female'),
#  ('Timmie', 'female'),
#  ('Babara', 'female'),
#  ('Pierre', 'male'),
#  ('Tova', 'female'),
#  ('Alec', 'male'),
#  ('Enya', 'female'),
#  ('Guthrey', 'male'),
#  ('Hyacintha', 'female'),
#  ('Bertina', 'female'),
#  ('Donnajean', 'female'),
#  ('Grayce', 'female'),
#  ('Bessie', 'female'),
#  ('Star', 'female'),
#  ('Fidela', 'female'),
#  ('Catarina', 'female'),
#  ('Kaja', 'female'),
#  ('Adella', 'female'),
#  ('Danyette', 'female'),
#  ('Sturgis', 'male'),
#  ('Hashim', 'male'),
#  ('Amelita', 'female'),
#  ('Mallory', 'female'),
#  ('Dorrie', 'female'),
#  ('Renel', 'female'),
#  ('Elysia', 'female'),
#  ('Ronnie', 'male'),
#  ('Rutger', 'male'),
#  ('Amie', 'female'),
#  ('Carolynn', 'female'),
#  ('Butch', 'male'),
#  ('Cori', 'female'),
#  ('Kristopher', 'male'),
#  ('Marguerite', 'female'),
#  ('Evette', 'female'),
#  ('Abbey', 'male'),
#  ('Jeffie', 'male'),
#  ('Franky', 'male'),
#  ('Petra', 'female'),
#  ('Eba', 'female'),
#  ('Teddy', 'female'),
#  ('Clarice', 'female'),
#  ('Eadith', 'female'),
#  ('Roselyn', 'female'),
#  ('Leanna', 'female'),
#  ('Delphinia', 'female'),
#  ('Laverne', 'female'),
#  ('Claudelle', 'female'),
#  ('Yetty', 'female'),
#  ('Nixie', 'female'),
#  ('Darell', 'female'),
#  ('Bary', 'male'),
#  ('Neal', 'male'),
#  ('Traver', 'male'),
#  ('Callie', 'female'),
#  ('Adrianne', 'female'),
#  ('Riva', 'female'),
#  ('Tamas', 'male'),
#  ('Kaile', 'female'),
#  ('Myrta', 'female'),
#  ('Debbie', 'female'),
#  ('Ezechiel', 'male'),
#  ('Sebastien', 'male'),
#  ('Bertha', 'female'),
#  ('John-Patrick', 'male'),
#  ('Aziz', 'male'),
#  ('Mahalia', 'female'),
#  ('Graehme', 'male'),
#  ('Carmelita', 'female'),
#  ('Frayda', 'female'),
#  ('Anallise', 'female'),
#  ('Daria', 'female'),
#  ('Bartie', 'male'),
#  ('Estrella', 'female'),
#  ('Derby', 'male'),
#  ('Archibald', 'male'),
#  ('Hasheem', 'male'),
#  ('Mame', 'female'),
#  ('Bettie', 'female'),
#  ('Calley', 'female'),
#  ('Kirk', 'male'),
#  ('Billie', 'male'),
#  ('Ferdinanda', 'female'),
#  ('Millie', 'female'),
#  ('Hendrick', 'male'),
#  ('Osborn', 'male'),
#  ('Tuck', 'male'),
#  ('Ephraim', 'male'),
#  ('Ede', 'female'),
#  ('Sally', 'female'),
#  ('Rodrigo', 'male'),
#  ('Zitella', 'female'),
#  ('Munroe', 'male'),
#  ('Donelle', 'female'),
#  ('Spiros', 'male'),
#  ('Murray', 'male'),
#  ('Amabelle', 'female'),
#  ('Cathi', 'female'),
#  ('Augustus', 'male'),
#  ('Vasily', 'male'),
#  ('Griffith', 'male'),
#  ('Jeana', 'female'),
#  ('Brigitta', 'female'),
#  ('Avrit', 'female'),
#  ('Daphna', 'female'),
#  ('Oprah', 'female'),
#  ('Andres', 'male'),
#  ('Andriana', 'female'),
#  ('Luigi', 'male'),
#  ('Kiele', 'female'),
#  ('Judy', 'female'),
#  ('Sigfrid', 'male'),
#  ('Kass', 'female'),
#  ('Yvonne', 'female'),
#  ('Marys', 'female'),
#  ('Bernete', 'female'),
#  ('Pansie', 'female'),
#  ('Aleck', 'male'),
#  ('Daffy', 'male'),
#  ('Annissa', 'female'),
#  ('Jeromy', 'male'),
#  ('Anissa', 'female'),
#  ('Lynelle', 'female'),
#  ('Gretel', 'female'),
#  ('Obadias', 'male'),
#  ('Junie', 'female'),
#  ('Ninon', 'female'),
#  ('Phylis', 'female'),
#  ('Atlante', 'female'),
#  ('Shelbi', 'female'),
#  ('Nicki', 'female'),
#  ('Aline', 'female'),
#  ('Pris', 'female'),
#  ('Margarethe', 'female'),
#  ('Madelene', 'female'),
#  ('Mead', 'female'),
#  ('Kingston', 'male'),
#  ('Odette', 'female'),
#  ('Jorrie', 'female'),
#  ('Zak', 'male'),
#  ('Lynne', 'female'),
#  ('Eliot', 'male'),
#  ('Muffin', 'male'),
#  ('Kristel', 'female'),
#  ('Shannon', 'female'),
#  ('Nell', 'female'),
#  ('Florice', 'female'),
#  ('Trevar', 'male'),
#  ('Deva', 'female'),
#  ('Bertine', 'female'),
#  ('Bunni', 'female'),
#  ('Tremain', 'male'),
#  ('Eugen', 'male'),
#  ('Mandie', 'female'),
#  ('Serena', 'female'),
#  ('Arlee', 'female'),
#  ('Onida', 'female'),
#  ('Cris', 'male'),
#  ('Lotta', 'female'),
#  ('Troy', 'male'),
#  ('Marlon', 'male'),
#  ('Thia', 'female'),
#  ('Andrea', 'female'),
#  ('Zacharie', 'male'),
#  ('Hanford', 'male'),
#  ('Liuka', 'female'),
#  ('Melonie', 'female'),
#  ('Wolfie', 'male'),
#  ('Lydia', 'female'),
#  ('Briney', 'female'),
#  ('Lorain', 'female'),
#  ('Elspeth', 'female'),
#  ('Page', 'female'),
#  ('Elyn', 'female'),
#  ('Lindsey', 'female'),
#  ('Perla', 'female'),
#  ('Shane', 'female'),
#  ('Gay', 'male'),
#  ('Lulu', 'female'),
#  ('Woochang', 'male'),
#  ('Adi', 'female'),
#  ('Larissa', 'female'),
#  ('Lauri', 'female'),
#  ('Gilda', 'female'),
#  ('Trip', 'male'),
#  ('Nathanael', 'male'),
#  ('Sherline', 'female'),
#  ('Scarlet', 'female'),
#  ('Loria', 'female'),
#  ('Meagan', 'female'),
#  ('Roberta', 'female'),
#  ('Joyann', 'female'),
#  ('Georg', 'male'),
#  ('Antonietta', 'female'),
#  ('Josi', 'female'),
#  ('Hulda', 'female'),
#  ('Marnie', 'female'),
#  ('Shirlene', 'female'),
#  ('Ambrosia', 'female'),
#  ('Alix', 'female'),
#  ('Ernesto', 'male'),
#  ('Silvio', 'male'),
#  ('Ozzie', 'male'),
#  ('Tina', 'female'),
#  ('Mavra', 'female'),
#  ('Saudra', 'female'),
#  ('Sylvan', 'male'),
#  ('Brewer', 'male'),
#  ('Yolane', 'female'),
#  ('Davon', 'male'),
#  ('Jocelyn', 'female'),
#  ('Loren', 'male'),
#  ('Devonne', 'female'),
#  ('Gavra', 'female'),
#  ('Vickie', 'female'),
#  ('Gabriela', 'female'),
#  ('Owen', 'male'),
#  ('Gene', 'male'),
#  ('Cameo', 'female'),
#  ('Mordecai', 'male'),
#  ('Hannie', 'female'),
#  ('Gusty', 'female'),
#  ('Reginald', 'male'),
#  ('Elayne', 'female'),
#  ('Sara-Ann', 'female'),
#  ('Marchall', 'male'),
#  ('Courtenay', 'female'),
#  ('Amalita', 'female'),
#  ('Janessa', 'female'),
#  ('Vinni', 'female'),
#  ('Yigal', 'male'),
#  ('Ronen', 'male'),
#  ('Millisent', 'female'),
#  ('Didi', 'female'),
#  ('Tudor', 'male'),
#  ('Annadiana', 'female'),
#  ('Allah', 'male'),
#  ('Alphonso', 'male'),
#  ('Hendrika', 'female'),
#  ('Allan', 'male'),
#  ('Izabel', 'female'),
#  ('Wilhelmina', 'female'),
#  ('Maryl', 'female'),
#  ('Inga', 'female'),
#  ('Webster', 'male'),
#  ('Aguste', 'male'),
#  ('Tandi', 'female'),
#  ('Dexter', 'male'),
#  ('Martainn', 'male'),
#  ('Angil', 'female'),
#  ('Price', 'male'),
#  ('Anett', 'female'),
#  ('Aidan', 'female'),
#  ('Regan', 'male'),
#  ('Meade', 'female'),
#  ('Emmeline', 'female'),
#  ('Pace', 'male'),
#  ('Arly', 'female'),
#  ('Jaquelin', 'female'),
#  ('Esteban', 'male'),
#  ('Malory', 'female'),
#  ('Averil', 'female'),
#  ('Anne-Mar', 'female'),
#  ('Leisha', 'female'),
#  ('Sheela', 'female'),
#  ('Vasili', 'male'),
#  ('Corrie', 'female'),
#  ('Melinde', 'female'),
#  ('Noam', 'male'),
#  ('Meier', 'male'),
#  ('Oralie', 'female'),
#  ('Carolyne', 'female'),
#  ('Sergio', 'male'),
#  ('Temple', 'male'),
#  ('Haley', 'male'),
#  ('Harald', 'male'),
#  ('Timmy', 'female'),
#  ('Zea', 'female'),
#  ('Mayda', 'female'),
#  ('Meryl', 'female'),
#  ('Valentina', 'female'),
#  ('Evie', 'female'),
#  ('Fey', 'female'),
#  ('Teriann', 'female'),
#  ('Tove', 'female'),
#  ('Fayina', 'female'),
#  ('Ashly', 'female'),
#  ('Rasia', 'female'),
#  ('Ilysa', 'female'),
#  ('Valeda', 'female'),
#  ('Happy', 'female'),
#  ('Marshall', 'male'),
#  ('Juliana', 'female'),
#  ('Chen', 'male'),
#  ('Bambie', 'female'),
#  ('Dianemarie', 'female'),
#  ('Christabel', 'female'),
#  ('Omar', 'male'),
#  ('Olivie', 'female'),
#  ('Tilly', 'female'),
#  ('Augustine', 'female'),
#  ('Kamillah', 'female'),
#  ('Stanfield', 'male'),
#  ('Dorian', 'male'),
#  ('Ora', 'female'),
#  ('Annemarie', 'female'),
#  ('Quill', 'male'),
#  ('Sydney', 'female'),
#  ('Peta', 'female'),
#  ('Glenn', 'female'),
#  ('Bree', 'female'),
#  ('Barbee', 'female'),
#  ('Fara', 'female'),
#  ('Erica', 'female'),
#  ('Lilas', 'female'),
#  ('Patsy', 'male'),
#  ('Laryssa', 'female'),
#  ('Stinky', 'male'),
#  ('Kam', 'male'),
#  ('Casandra', 'female'),
#  ('Tremayne', 'male'),
#  ('Diena', 'female'),
#  ('Adelice', 'female'),
#  ('Georgeta', 'female'),
#  ('Myrilla', 'female'),
#  ('Gifford', 'male'),
#  ('Jimmie', 'male'),
#  ('Roni', 'male'),
#  ('Ricky', 'female'),
#  ('Cookie', 'female'),
#  ('Virginia', 'female'),
#  ('Correna', 'female'),
#  ('Leonard', 'male'),
#  ('Friedrich', 'male'),
#  ('Freda', 'female'),
#  ('Michale', 'male'),
#  ('Kiah', 'female'),
#  ('Kissiah', 'female'),
#  ('Florance', 'female'),
#  ('Demetre', 'male'),
#  ('Oral', 'male'),
#  ('Adrien', 'female'),
#  ('Giorgio', 'male'),
#  ('Antoni', 'male'),
#  ('Tedmund', 'male'),
#  ('Sharona', 'female'),
#  ('Dick', 'male'),
#  ('Jessalin', 'female'),
#  ('Fairfax', 'male'),
#  ('Kinna', 'female'),
#  ('Brandon', 'male'),
#  ('Hanny', 'female'),
#  ('Briggs', 'male'),
#  ('Michaeline', 'female'),
#  ('Almire', 'female'),
#  ('Paolo', 'male'),
#  ('Julia', 'female'),
#  ('Carter', 'male'),
#  ('Catlaina', 'female'),
#  ('Marv', 'male'),
#  ('Tadd', 'male'),
#  ('Aamir', 'male'),
#  ('Cheston', 'male'),
#  ('Shanta', 'female'),
#  ('Winfred', 'male'),
#  ('Scotti', 'male'),
#  ('Theresa', 'female'),
#  ('Alysia', 'female'),
#  ('Georgia', 'male'),
#  ('Glenda', 'female'),
#  ('Aguinaldo', 'male'),
#  ('Norman', 'male'),
#  ('Adam', 'male'),
#  ('Mela', 'female'),
#  ('Jennilee', 'female'),
#  ('Jessika', 'female'),
#  ('Gert', 'female'),
#  ('Allsun', 'female'),
#  ('Maddie', 'female'),
#  ('Pierette', 'female'),
#  ('Tessie', 'female'),
#  ('Robinetta', 'female'),
#  ('Cordula', 'female'),
#  ('Shepard', 'male'),
#  ('Christy', 'male'),
#  ('Shem', 'male'),
#  ('Husein', 'male'),
#  ('Freddie', 'female'),
#  ('Hannis', 'female'),
#  ('Fitz', 'male'),
#  ('Cathe', 'female'),
#  ("E'Lane", 'female'),
#  ('Zorro', 'male'),
#  ('Adrea', 'female'),
#  ('Ailina', 'female'),
#  ('Stewart', 'male'),
#  ('Dmitri', 'male'),
#  ('Allegra', 'female'),
#  ('Shelly', 'female'),
#  ('Ingaborg', 'female'),
#  ('Pattie', 'male'),
#  ('Garfield', 'male'),
#  ('Mohan', 'male'),
#  ('Verne', 'male'),
#  ('LeeAnn', 'female'),
#  ('Nikolia', 'female'),
#  ('Neala', 'female'),
#  ('Skye', 'male'),
#  ('Sly', 'male'),
#  ('Jolyn', 'female'),
#  ('Dulcy', 'female'),
#  ('Ranice', 'female'),
#  ('Phaidra', 'female'),
#  ('Pegeen', 'female'),
#  ('Jonell', 'female'),
#  ('Norene', 'female'),
#  ('Drake', 'male'),
#  ('Lynette', 'female'),
#  ('Dustin', 'male'),
#  ('Rania', 'female'),
#  ('Rainer', 'male'),
#  ('Obie', 'male'),
#  ('Erna', 'female'),
#  ('Lorianna', 'female'),
#  ('Alfie', 'female'),
#  ('Kaycee', 'female'),
#  ('Ansel', 'male'),
#  ('Gabriellia', 'female'),
#  ('Cheslie', 'female'),
#  ('Rodrique', 'male'),
#  ('Tera', 'female'),
#  ('Roderick', 'male'),
#  ('Kalle', 'male'),
#  ('Orville', 'male'),
#  ('Odysseus', 'male'),
#  ('Hellene', 'female'),
#  ('Nickie', 'male'),
#  ('Noemi', 'female'),
#  ('Albert', 'male'),
#  ('Inez', 'female'),
#  ('Madeleine', 'female'),
#  ('Beauregard', 'male'),
#  ('Ted', 'female'),
#  ('Virgie', 'male'),
#  ('Levi', 'male'),
#  ('Terri', 'female'),
#  ('Kitty', 'female'),
#  ('Verina', 'female'),
#  ('Tam', 'male'),
#  ('Julina', 'female'),
#  ('Fanechka', 'female'),
#  ('Morna', 'female'),
#  ('Magdalena', 'female'),
#  ('Blinnie', 'female'),
#  ('Marie-Ann', 'female'),
#  ('Wynn', 'male'),
#  ('Samuella', 'female'),
#  ('Edin', 'female'),
#  ('Dodi', 'female'),
#  ('Maxie', 'male'),
#  ('Bonni', 'female'),
#  ('Kenna', 'female'),
#  ('Joye', 'female'),
#  ('Camel', 'female'),
#  ('Adoree', 'female'),
#  ('Noella', 'female'),
#  ('Mervin', 'male'),
#  ('Alexina', 'female'),
#  ('Karon', 'female'),
#  ('Natka', 'female'),
#  ('Chad', 'female'),
#  ('Gabie', 'female'),
#  ('Bernadine', 'female'),
#  ('Dolores', 'female'),
#  ('Nikoletta', 'female'),
#  ('Lisetta', 'female'),
#  ('Tabbi', 'female'),
#  ('Stearne', 'male'),
#  ('Abelard', 'male'),
#  ('Townie', 'male'),
#  ('Erinn', 'female'),
#  ('Guglielma', 'female'),
#  ('Charyl', 'female'),
#  ('Tommy', 'male'),
#  ('Dugan', 'male'),
#  ('Belia', 'female'),
#  ('Susanna', 'female'),
#  ('Harli', 'female'),
#  ('Roxanna', 'female'),
#  ('Wendell', 'male'),
#  ('Maribelle', 'female'),
#  ('Beret', 'female'),
#  ('Leila', 'female'),
#  ('Rozanne', 'female'),
#  ('Kayley', 'female'),
#  ('Mable', 'female'),
#  ('Tommie', 'male'),
#  ('Stephanie', 'female'),
#  ('Julee', 'female'),
#  ('Cooper', 'male'),
#  ('Florie', 'female'),
#  ('Moselle', 'female'),
#  ('Jocelin', 'female'),
#  ('Prudence', 'female'),
#  ('Clarie', 'female'),
#  ('Francesmary', 'female'),
#  ('Ardenia', 'female'),
#  ('Conan', 'male'),
#  ('Kellen', 'female'),
#  ('Trudey', 'female'),
#  ('Aggy', 'female'),
#  ('Merle', 'male'),
#  ('Janey', 'female'),
#  ('Kylila', 'female'),
#  ('Raine', 'female'),
#  ('Ignazio', 'male'),
#  ('Veronika', 'female'),
#  ('Raynor', 'male'),
#  ('Marillin', 'female'),
#  ('Lebbie', 'female'),
#  ('Vibhu', 'male'),
#  ('Tedd', 'male'),
#  ('Rasla', 'female'),
#  ('Pincus', 'male'),
#  ('Kariotta', 'female'),
#  ('Lina', 'female'),
#  ('Leland', 'male'),
#  ('Katheleen', 'female'),
#  ('Cain', 'male'),
#  ('Stavros', 'male'),
#  ('Bette', 'female'),
#  ('Lacee', 'female'),
#  ('Kelila', 'female'),
#  ('Douggie', 'male'),
#  ('Agneta', 'female'),
#  ('Jenda', 'female'),
#  ('Heathcliff', 'male'),
#  ('Cosette', 'female'),
#  ('Lucien', 'male'),
#  ('Rosaline', 'female'),
#  ('Jean-Christophe', 'male'),
#  ('Chet', 'male'),
#  ('Marilee', 'female'),
#  ('Evvie', 'female'),
#  ('Stefa', 'female'),
#  ('Elnar', 'male'),
#  ('Zarla', 'female'),
#  ('Nat', 'male'),
#  ('Jae', 'male'),
#  ('Mignonne', 'female'),
#  ('Trude', 'female'),
#  ('Barny', 'male'),
#  ('Torie', 'female'),
#  ('Mustafa', 'male'),
#  ('Sidney', 'male'),
#  ('Maurine', 'female'),
#  ('Corry', 'female'),
#  ('Rebecca', 'female'),
#  ('Philly', 'female'),
#  ('Susann', 'female'),
#  ('Ninnette', 'female'),
#  ('Larina', 'female'),
#  ('Bernice', 'female'),
#  ('Danyelle', 'female'),
#  ('Trisha', 'female'),
#  ('Neely', 'female'),
#  ('Caryl', 'male'),
#  ('Jacqueline', 'female'),
#  ('Giacinta', 'female'),
#  ('Alyss', 'female'),
#  ('Clarisse', 'female'),
#  ('Salome', 'female'),
#  ('Renie', 'female'),
#  ('Eula', 'female'),
#  ('Apostolos', 'male'),
#  ('Freemon', 'male'),
#  ('Helmuth', 'male'),
#  ('Koren', 'female'),
#  ('Tyler', 'male'),
#  ('Claude', 'male'),
#  ('Tabitha', 'female'),
#  ('Tarrah', 'female'),
#  ('Henrietta', 'female'),
#  ('Cecil', 'male'),
#  ('Blake', 'female'),
#  ('Wilburn', 'male'),
#  ('Phedra', 'female'),
#  ('Nicole', 'female'),
#  ('Alis', 'female'),
#  ('Cam', 'female'),
#  ('Morris', 'male'),
#  ('Brunhilde', 'female'),
#  ('Tani', 'female'),
#  ('Mireielle', 'female'),
#  ('Anders', 'male'),
#  ('Bernadina', 'female'),
#  ('Fawn', 'female'),
#  ('Northrop', 'male'),
#  ('Bellina', 'female'),
#  ('Korney', 'female'),
#  ('Martyn', 'male'),
#  ('Odie', 'male'),
#  ('Edy', 'female'),
#  ('Rosanna', 'female'),
#  ('Hermy', 'male'),
#  ('Karmen', 'female'),
#  ('Stearn', 'male'),
#  ('Gweneth', 'female'),
#  ('Francisca', 'female'),
#  ('Eva', 'female'),
#  ('Sibyl', 'male'),
#  ('Valeria', 'female'),
#  ('Skyler', 'male'),
#  ('Arnie', 'male'),
#  ('Marcela', 'female'),
#  ('Megan', 'female'),
#  ('Ina', 'female'),
#  ('Renato', 'male'),
#  ('Veronike', 'female'),
#  ('Kate', 'female'),
#  ('Chiquita', 'female'),
#  ('Portia', 'female'),
#  ('Tome', 'male'),
#  ('Andria', 'female'),
#  ('Harwell', 'male'),
#  ('Agustin', 'male'),
#  ('Brande', 'female'),
#  ('Dorothee', 'female'),
#  ('Gonzales', 'male'),
#  ('Stephanus', 'male'),
#  ('Teodoro', 'male'),
#  ('Fania', 'female'),
#  ('Neddie', 'male'),
#  ('Shayna', 'female'),
#  ('Sonnie', 'male'),
#  ('Rubie', 'female'),
#  ('Dottie', 'female'),
#  ('Kristine', 'female'),
#  ('Lucia', 'female'),
#  ('Walt', 'male'),
#  ('Ethan', 'male'),
#  ('Gino', 'male'),
#  ('Ella', 'female'),
#  ('Matthiew', 'male'),
#  ('Brit', 'female'),
#  ('Howard', 'male'),
#  ('Barb', 'female'),
#  ('Gloria', 'female'),
#  ('Leshia', 'female'),
#  ('Idaline', 'female'),
#  ('Celisse', 'female'),
#  ('Wake', 'male'),
#  ('Madelin', 'female'),
#  ('Therine', 'female'),
#  ('Carina', 'female'),
#  ('Lazlo', 'male'),
#  ('Roxy', 'female'),
#  ('Amalea', 'female'),
#  ('Marlo', 'male'),
#  ('Demetra', 'female'),
#  ('Humbert', 'male'),
#  ('Corliss', 'female'),
#  ('Shira', 'female'),
#  ('Tobey', 'female'),
#  ('Ida', 'female'),
#  ('Paul', 'male'),
#  ('Leonidas', 'male'),
#  ('Karla', 'female'),
#  ('Bendite', 'female'),
#  ('Winn', 'male'),
#  ('Janine', 'female'),
#  ('Meris', 'female'),
#  ('Jehu', 'male'),
#  ('Lucinda', 'female'),
#  ('Clarisa', 'female'),
#  ('Jose', 'male'),
#  ('Salman', 'male'),
#  ('Bobina', 'female'),
#  ('Tabby', 'female'),
#  ('Coriss', 'female'),
#  ('Purcell', 'male'),
#  ('Onlea', 'female'),
#  ('Cristabel', 'female'),
#  ('Clara', 'female'),
#  ('Sivert', 'male'),
#  ('Mohammed', 'male'),
#  ('Beck', 'male'),
#  ('Olimpia', 'female'),
#  ('Lew', 'male'),
#  ('Francesco', 'male'),
#  ('Karil', 'female'),
#  ('Edith', 'female'),
#  ('Anais', 'female'),
#  ('Gui', 'female'),
#  ('Shoshie', 'female'),
#  ('Lorrayne', 'female'),
#  ('Barde', 'male'),
#  ('Waldo', 'male'),
#  ('Helene', 'female'),
#  ('Cornelia', 'female'),
#  ('Darius', 'male'),
#  ('Florida', 'female'),
#  ('Moises', 'male'),
#  ('Beatriz', 'female'),
#  ('Ariella', 'female'),
#  ('Wilfrid', 'male'),
#  ('Fredi', 'female'),
#  ('Maisey', 'female'),
#  ('Wilbert', 'male'),
#  ('Doria', 'female'),
#  ('Saunder', 'male'),
#  ('Drew', 'female'),
#  ('Camella', 'female'),
#  ('Kaari', 'female'),
#  ('Jordana', 'female'),
#  ('Scot', 'male'),
#  ('Eleonore', 'female'),
#  ('Alene', 'female'),
#  ('Giacomo', 'male'),
#  ('Zachariah', 'male'),
#  ('Reena', 'female'),
#  ('Dixie', 'female'),
#  ('Reza', 'male'),
#  ('Kerianne', 'female'),
#  ('Puff', 'male'),
#  ('Gunner', 'male'),
#  ('Luciano', 'male'),
#  ('Denice', 'female'),
#  ('Ike', 'female'),
#  ('Rodge', 'male'),
#  ('Tia', 'female'),
#  ('Selby', 'male'),
#  ('Nilson', 'male'),
#  ('Jilleen', 'female'),
#  ('Rourke', 'male'),
#  ('Caterina', 'female'),
#  ('Jania', 'female'),
#  ('Trish', 'female'),
#  ('Jo-Ann', 'female'),
#  ('Kessiah', 'female'),
#  ('Elisha', 'male'),
#  ('Sibel', 'female'),
#  ('Davy', 'male'),
#  ('Angelo', 'male'),
#  ('Dyanna', 'female'),
#  ('Tallia', 'female'),
#  ('Brear', 'female'),
#  ('Lee', 'male'),
#  ('Eve', 'female'),
#  ('Ashely', 'female'),
#  ('Elvira', 'female'),
#  ('Jehanna', 'female'),
#  ('Mortimer', 'male'),
#  ('Eric', 'male'),
#  ('Morgan', 'male'),
#  ('Ilka', 'female'),
#  ('Gere', 'male'),
#  ('Neville', 'male'),
#  ('Wilburt', 'male'),
#  ('Carolina', 'female'),
#  ('Claudie', 'female'),
#  ('Jefferey', 'male'),
#  ('Cleo', 'female'),
#  ('Harvey', 'male'),
#  ('Benedict', 'male'),
#  ('Shane', 'male'),
#  ('Lelah', 'female'),
#  ('Oralle', 'female'),
#  ('Clay', 'male'),
#  ('Raquel', 'female'),
#  ('Lin', 'female'),
#  ('Lauree', 'female'),
#  ('Odilia', 'female'),
#  ('Kevan', 'male'),
#  ('Vinita', 'female'),
#  ('Vince', 'male'),
#  ('Marissa', 'female'),
#  ('Nathalie', 'female'),
#  ('Doro', 'female'),
#  ('Tobie', 'male'),
#  ('Paton', 'male'),
#  ('Kaleena', 'female'),
#  ('Britt', 'female'),
#  ('Helen', 'female'),
#  ('Kimberlee', 'female'),
#  ('Kim', 'male'),
#  ('Fitzgerald', 'male'),
#  ('Karrah', 'female'),
#  ('Amata', 'female'),
#  ('Kirstyn', 'female'),
#  ('Sissy', 'female'),
#  ('Evita', 'female'),
#  ('Donnie', 'male'),
#  ('Sargent', 'male'),
#  ('Paulita', 'female'),
#  ('Ardene', 'female'),
#  ('Tiffanie', 'female'),
#  ('Selena', 'female'),
#  ('Charlotte', 'female'),
#  ('Stig', 'male'),
#  ('Issie', 'female'),
#  ('Bartholomeus', 'male'),
#  ('Sher', 'female'),
#  ('Tiffy', 'female'),
#  ('Sarine', 'female'),
#  ('Madonna', 'female'),
#  ('Minni', 'female'),
#  ('Barthel', 'male'),
#  ('Annamaria', 'female'),
#  ('Inger', 'female'),
#  ('Hetti', 'female'),
#  ('Valera', 'female'),
#  ('Gilberto', 'male'),
#  ('Alford', 'male'),
#  ('Pryce', 'male'),
#  ('Sean', 'female'),
#  ('Jean', 'male'),
#  ('Chelsae', 'female'),
#  ('Dell', 'male'),
#  ('Levon', 'male'),
#  ('Harley', 'male'),
#  ('Saul', 'male'),
#  ('Katha', 'female'),
#  ('Paula', 'female'),
#  ('Domenic', 'male'),
#  ('Candide', 'female'),
#  ('Trixie', 'female'),
#  ('Ruthe', 'female'),
#  ('Yacov', 'male'),
#  ('Ware', 'male'),
#  ('Sergent', 'male'),
#  ('Florri', 'female'),
#  ('Anni', 'female'),
#  ('Ammamaria', 'female'),
#  ('Morena', 'female'),
#  ('Bellamy', 'female'),
#  ('Maryrose', 'female'),
#  ('Lavena', 'female'),
#  ('Cleland', 'male'),
#  ('Jerold', 'male'),
#  ('Melania', 'female'),
#  ('Ranna', 'female'),
#  ('Analise', 'female'),
#  ('Frederica', 'female'),
#  ('Xaviera', 'female'),
#  ('Chelsea', 'female'),
#  ('Desmund', 'male'),
#  ('Jeff', 'male'),
#  ('Ceil', 'female'),
#  ('Harmon', 'male'),
#  ('Ryann', 'female'),
#  ('Natalee', 'female'),
#  ('Jennie', 'female'),
#  ('Christabelle', 'female'),
#  ('Eugene', 'male'),
#  ('Iolande', 'female'),
#  ('Avrom', 'male'),
#  ('Les', 'male'),
#  ('Neda', 'female'),
#  ('Britaney', 'female'),
#  ('Angela', 'female'),
#  ('Vassili', 'male'),
#  ('Vally', 'female'),
#  ('Ethyl', 'female'),
#  ('Dwaine', 'male'),
#  ('Haywood', 'male'),
#  ('Ardra', 'female'),
#  ('Darwin', 'male'),
#  ('Berkie', 'male'),
#  ('Stanford', 'male'),
#  ('Donielle', 'female'),
#  ('Tammie', 'male'),
#  ('Ciel', 'female'),
#  ('Edward', 'male'),
#  ('Elizabeth', 'female'),
#  ('Annabell', 'female'),
#  ('Daphene', 'female'),
#  ('Darline', 'female'),
#  ('Marylee', 'female'),
#  ('Lynnell', 'female'),
#  ('Carleigh', 'male'),
#  ('Dyan', 'female'),
#  ('Thaddius', 'male'),
#  ('Dorelle', 'female'),
#  ('Joelle', 'female'),
#  ('Dianna', 'female'),
#  ('Melina', 'female'),
#  ('Kelly', 'female'),
#  ('Brodie', 'male'),
#  ('Juline', 'female'),
#  ('Violet', 'female'),
#  ('Roscoe', 'male'),
#  ('Burl', 'male'),
#  ('Carline', 'female'),
#  ('Kirby', 'female'),
#  ('Kaylyn', 'female'),
#  ('Chuck', 'male'),
#  ('Louella', 'female'),
#  ('Shandra', 'female'),
#  ('Klara', 'female'),
#  ('Demeter', 'female'),
#  ('Marry', 'female'),
#  ('Clarence', 'male'),
#  ('Bessy', 'female'),
#  ('Mellicent', 'female'),
#  ('Jedediah', 'male'),
#  ('Tull', 'male'),
#  ('Raf', 'female'),
#  ('Mort', 'male'),
#  ('Abdullah', 'male'),
#  ('Pepito', 'male'),
#  ('Leah', 'female'),
#  ('Kandace', 'female'),
#  ('Torry', 'male'),
#  ('Camala', 'female'),
#  ('Tracie', 'male'),
#  ('Loraine', 'female'),
#  ('Marcus', 'male'),
#  ('Dennie', 'female'),
#  ('Lind', 'female'),
#  ('Lanny', 'female'),
#  ('Zia', 'female'),
#  ('Prudy', 'female'),
#  ('Robena', 'female'),
#  ('Inesita', 'female'),
#  ('Erma', 'female'),
#  ('Abdul', 'male'),
#  ('Dynah', 'female'),
#  ('Florinda', 'female'),
#  ('Dirk', 'male'),
#  ('Rahul', 'male'),
#  ('Lorelei', 'female'),
#  ('Lambert', 'male'),
#  ('Sheelah', 'female'),
#  ('Raul', 'male'),
#  ('Talia', 'female'),
#  ('Maude', 'female'),
#  ('Fawna', 'female'),
#  ('Lex', 'male'),
#  ('Rozanna', 'female'),
#  ('Henriette', 'female'),
#  ('Mitchel', 'male'),
#  ('Mugsy', 'male'),
#  ('Tomlin', 'male'),
#  ('Carie', 'female'),
#  ('Ahmad', 'male'),
#  ('Anet', 'female'),
#  ('Ebeneser', 'male'),
#  ('Kaia', 'female'),
#  ('Sonnnie', 'female'),
#  ('Robin', 'male'),
#  ('Nathanil', 'male'),
#  ('Van', 'male'),
#  ('Nerissa', 'female'),
#  ('Deonne', 'female'),
#  ('Petronille', 'female'),
#  ('Norina', 'female'),
#  ('Yalonda', 'female'),
#  ('Carmella', 'female'),
#  ('Sibby', 'female'),
#  ('Armand', 'male'),
#  ('Jessalyn', 'female'),
#  ('Collette', 'female'),
#  ('Corey', 'female'),
#  ('Whitney', 'female'),
#  ('Shantee', 'female'),
#  ('Winston', 'male'),
#  ('Waleed', 'male'),
#  ('Yvette', 'female'),
#  ('Nissie', 'female'),
#  ('Rutter', 'male'),
#  ('Nigel', 'male'),
#  ('Odetta', 'female'),
#  ('Gunvor', 'female'),
#  ('Rosabella', 'female'),
#  ...]

# %%
import random 
random.shuffle(labeled_names)

# %%
train_set,test_set = featuresets[5000:],featuresets[:2000]
import nltk 
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('David'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Obama '))
# Out:
# 'female'

# %%
classifier.classify(gender_features('Shanmukh '))
# Out:
# 'female'

# %%
print(nltk.classify.accuracy(classifier,test_set))
# Out:
# 0.742

# %%
#3. count vectorizer 
from sklearn.feature_extraction.text import CountVectorizer 
vect = CountVectorizer(binary=True)
corpus = ["Hi this is natural langauage processing, jupyter "]

# %%
vect.fit(corpus)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
vocab = vect.vocabulary_

# %%
for key in sorted(vocab.keys()):
    print("{}:{}".format(key,vocab[key]))
# Out:
# hi:0
# is:1
# jupyter:2
# langauage:3
# natural:4
# processing:5
# this:6

# %%
print(vect.transform(["This is a good optical illusion "]).toarray())
# Out:
# [[0 1 0 0 0 0 1]]

# %%
print(vect.transform(["This is a good good optical illusion "]).toarray())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fa718c8dda11> in <module>
# ----> 1 print(vect.transform(["This is a good good optical illusion "]).toarray())
#       2 from sklearn.metrics.pairwise import cosine_similarity
#       3 similarity = cosine_similarity(vect.transform(["Google Cloud Vision is a character recognition engine"]).toarray(), vect.transform(["OCR is an optical character recognition engine"]).toarray())
#       4 similarity
#
# NameError: name 'vect' is not defined

# %%
from nltk.corpus import names

# %%
names.words()
# Out:
# ['Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abra',
#  'Acacia',
#  'Ada',
#  'Adah',
#  'Adaline',
#  'Adara',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
#  'Aime',
#  'Aimee',
#  'Aimil',
#  'Aina',
#  'Aindrea',
#  'Ainslee',
#  'Ainsley',
#  'Ainslie',
#  'Ajay',
#  'Alaine',
#  'Alameda',
#  'Alana',
#  'Alanah',
#  'Alane',
#  'Alanna',
#  'Alayne',
#  'Alberta',
#  'Albertina',
#  'Albertine',
#  'Albina',
#  'Alecia',
#  'Aleda',
#  'Aleece',
#  'Aleecia',
#  'Aleen',
#  'Alejandra',
#  'Alejandrina',
#  'Alena',
#  'Alene',
#  'Alessandra',
#  'Aleta',
#  'Alethea',
#  'Alex',
#  'Alexa',
#  'Alexandra',
#  'Alexandrina',
#  'Alexi',
#  'Alexia',
#  'Alexina',
#  'Alexine',
#  'Alexis',
#  'Alfie',
#  'Alfreda',
#  'Ali',
#  'Alia',
#  'Alica',
#  'Alice',
#  'Alicea',
#  'Alicia',
#  'Alida',
#  'Alidia',
#  'Alina',
#  'Aline',
#  'Alis',
#  'Alisa',
#  'Alisha',
#  'Alison',
#  'Alissa',
#  'Alisun',
#  'Alix',
#  'Aliza',
#  'Alla',
#  'Alleen',
#  'Allegra',
#  'Allene',
#  'Alli',
#  'Allianora',
#  'Allie',
#  'Allina',
#  'Allis',
#  'Allison',
#  'Allissa',
#  'Allsun',
#  'Ally',
#  'Allyce',
#  'Allyn',
#  'Allys',
#  'Allyson',
#  'Alma',
#  'Almeda',
#  'Almeria',
#  'Almeta',
#  'Almira',
#  'Almire',
#  'Aloise',
#  'Aloisia',
#  'Aloysia',
#  'Alpa',
#  'Alta',
#  'Althea',
#  'Alvera',
#  'Alvina',
#  'Alvinia',
#  'Alvira',
#  'Alyce',
#  'Alyda',
#  'Alys',
#  'Alysa',
#  'Alyse',
#  'Alysia',
#  'Alyson',
#  'Alyss',
#  'Alyssa',
#  'Amabel',
#  'Amabelle',
#  'Amalea',
#  'Amalee',
#  'Amaleta',
#  'Amalia',
#  'Amalie',
#  'Amalita',
#  'Amalle',
#  'Amanda',
#  'Amandi',
#  'Amandie',
#  'Amandy',
#  'Amara',
#  'Amargo',
#  'Amata',
#  'Amber',
#  'Amberly',
#  'Ambrosia',
#  'Ambur',
#  'Ame',
#  'Amelia',
#  'Amelie',
#  'Amelina',
#  'Ameline',
#  'Amelita',
#  'Ami',
#  'Amie',
#  'Amity',
#  'Ammamaria',
#  'Amy',
#  'Ana',
#  'Anabel',
#  'Anabella',
#  'Anabelle',
#  'Anais',
#  'Analiese',
#  'Analise',
#  'Anallese',
#  'Anallise',
#  'Anastasia',
#  'Anastasie',
#  'Anastassia',
#  'Anatola',
#  'Andee',
#  'Andi',
#  'Andie',
#  'Andra',
#  'Andrea',
#  'Andreana',
#  'Andree',
#  'Andrei',
#  'Andria',
#  'Andriana',
#  'Andriette',
#  'Andromache',
#  'Andromeda',
#  'Andy',
#  'Anestassia',
#  'Anet',
#  'Anett',
#  'Anetta',
#  'Anette',
#  'Ange',
#  'Angel',
#  'Angela',
#  'Angele',
#  'Angelia',
#  'Angelica',
#  'Angelika',
#  'Angelina',
#  'Angeline',
#  'Angelique',
#  'Angelita',
#  'Angelle',
#  'Angie',
#  'Angil',
#  'Angy',
#  'Ania',
#  'Anica',
#  'Anissa',
#  'Anita',
#  'Anitra',
#  'Anja',
#  'Anjanette',
#  'Anjela',
#  'Ann',
#  'Ann-Mari',
#  'Ann-Marie',
#  'Anna',
#  'Anna-Diana',
#  'Anna-Diane',
#  'Anna-Maria',
#  'Annabal',
#  'Annabel',
#  'Annabela',
#  'Annabell',
#  'Annabella',
#  'Annabelle',
#  'Annadiana',
#  'Annadiane',
#  'Annalee',
#  'Annalena',
#  'Annaliese',
#  'Annalisa',
#  'Annalise',
#  'Annalyse',
#  'Annamari',
#  'Annamaria',
#  'Annamarie',
#  'Anne',
#  'Anne-Corinne',
#  'Anne-Mar',
#  'Anne-Marie',
#  'Annecorinne',
#  'Anneliese',
#  'Annelise',
#  'Annemarie',
#  'Annetta',
#  'Annette',
#  'Anni',
#  'Annice',
#  'Annie',
#  'Annissa',
#  'Annmaria',
#  'Annmarie',
#  'Annnora',
#  'Annora',
#  'Anny',
#  'Anselma',
#  'Ansley',
#  'Anstice',
#  'Anthe',
#  'Anthea',
#  'Anthia',
#  'Antoinette',
#  'Antonella',
#  'Antonetta',
#  'Antonia',
#  'Antonie',
#  'Antonietta',
#  'Antonina',
#  'Anya',
#  'Aphrodite',
#  'Appolonia',
#  'April',
#  'Aprilette',
#  'Ara',
#  'Arabel',
#  'Arabela',
#  'Arabele',
#  'Arabella',
#  'Arabelle',
#  'Arda',
#  'Ardath',
#  'Ardeen',
#  'Ardelia',
#  'Ardelis',
#  'Ardella',
#  'Ardelle',
#  'Arden',
#  'Ardene',
#  'Ardenia',
#  'Ardine',
#  'Ardis',
#  'Ardith',
#  'Ardra',
#  'Ardyce',
#  'Ardys',
#  'Ardyth',
#  'Aretha',
#  'Ariadne',
#  'Ariana',
#  'Arianne',
#  'Aridatha',
#  'Ariel',
#  'Ariela',
#  'Ariella',
#  'Arielle',
#  'Arlana',
#  'Arlee',
#  'Arleen',
#  'Arlen',
#  'Arlena',
#  'Arlene',
#  'Arleta',
#  'Arlette',
#  'Arleyne',
#  'Arlie',
#  'Arliene',
#  'Arlina',
#  'Arlinda',
#  'Arline',
#  'Arly',
#  'Arlyn',
#  'Arlyne',
#  'Aryn',
#  'Ashely',
#  'Ashlee',
#  'Ashleigh',
#  'Ashlen',
#  'Ashley',
#  'Ashli',
#  'Ashlie',
#  'Ashly',
#  'Asia',
#  'Astra',
#  'Astrid',
#  'Astrix',
#  'Atalanta',
#  'Athena',
#  'Athene',
#  'Atlanta',
#  'Atlante',
#  'Auberta',
#  'Aubine',
#  'Aubree',
#  'Aubrette',
#  'Aubrey',
#  'Aubrie',
#  'Aubry',
#  'Audi',
#  'Audie',
#  'Audra',
#  'Audre',
#  'Audrey',
#  'Audrie',
#  'Audry',
#  'Audrye',
#  'Audy',
#  'Augusta',
#  'Auguste',
#  'Augustina',
#  'Augustine',
#  'Aura',
#  'Aurea',
#  'Aurel',
#  'Aurelea',
#  'Aurelia',
#  'Aurelie',
#  'Auria',
#  'Aurie',
#  'Aurilia',
#  'Aurlie',
#  'Auroora',
#  'Aurora',
#  'Aurore',
#  'Austin',
#  'Austina',
#  'Austine',
#  'Ava',
#  'Aveline',
#  'Averil',
#  'Averyl',
#  'Avie',
#  'Avis',
#  'Aviva',
#  'Avivah',
#  'Avril',
#  'Avrit',
#  'Ayn',
#  'Bab',
#  'Babara',
#  'Babette',
#  'Babita',
#  'Babs',
#  'Bambi',
#  'Bambie',
#  'Bamby',
#  'Barb',
#  'Barbabra',
#  'Barbara',
#  'Barbara-Anne',
#  'Barbaraanne',
#  'Barbe',
#  'Barbee',
#  'Barbette',
#  'Barbey',
#  'Barbi',
#  'Barbie',
#  'Barbra',
#  'Barby',
#  'Bari',
#  'Barrie',
#  'Barry',
#  'Basia',
#  'Bathsheba',
#  'Batsheva',
#  'Bea',
#  'Beatrice',
#  'Beatrisa',
#  'Beatrix',
#  'Beatriz',
#  'Beau',
#  'Bebe',
#  'Becca',
#  'Becka',
#  'Becki',
#  'Beckie',
#  'Becky',
#  'Bee',
#  'Beilul',
#  'Beitris',
#  'Bekki',
#  'Bel',
#  'Belia',
#  'Belicia',
#  'Belinda',
#  'Belita',
#  'Bell',
#  'Bella',
#  'Bellamy',
#  'Bellanca',
#  'Belle',
#  'Bellina',
#  'Belva',
#  'Belvia',
#  'Bendite',
#  'Benedetta',
#  'Benedicta',
#  'Benedikta',
#  'Benetta',
#  'Benita',
#  'Benni',
#  'Bennie',
#  'Benny',
#  'Benoite',
#  'Berenice',
#  'Beret',
#  'Berget',
#  'Berna',
#  'Bernadene',
#  'Bernadette',
#  'Bernadina',
#  'Bernadine',
#  'Bernardina',
#  'Bernardine',
#  'Bernelle',
#  'Bernete',
#  'Bernetta',
#  'Bernette',
#  'Berni',
#  'Bernice',
#  'Bernie',
#  'Bernita',
#  'Berny',
#  'Berri',
#  'Berrie',
#  'Berry',
#  'Bert',
#  'Berta',
#  'Berte',
#  'Bertha',
#  'Berthe',
#  'Berti',
#  'Bertie',
#  'Bertina',
#  'Bertine',
#  'Berty',
#  'Beryl',
#  'Beryle',
#  'Bess',
#  'Bessie',
#  'Bessy',
#  'Beth',
#  'Bethanne',
#  'Bethany',
#  'Bethena',
#  'Bethina',
#  'Betsey',
#  'Betsy',
#  'Betta',
#  'Bette',
#  'Bette-Ann',
#  'Betteann',
#  'Betteanne',
#  'Betti',
#  'Bettie',
#  'Bettina',
#  'Bettine',
#  'Betty',
#  'Bettye',
#  'Beulah',
#  'Bev',
#  'Beverie',
#  'Beverlee',
#  'Beverlie',
#  'Beverly',
#  'Bevvy',
#  'Bianca',
#  'Bianka',
#  'Biddy',
#  'Bidget',
#  'Bill',
#  'Billi',
#  'Billie',
#  'Billy',
#  'Binni',
#  'Binnie',
#  'Binny',
#  'Bird',
#  'Birdie',
#  'Birgit',
#  'Birgitta',
#  'Blair',
#  'Blaire',
#  'Blake',
#  'Blakelee',
#  'Blakeley',
#  'Blanca',
#  'Blanch',
#  'Blancha',
#  'Blanche',
#  'Blinni',
#  'Blinnie',
#  'Blinny',
#  'Bliss',
#  'Blisse',
#  'Blithe',
#  'Blondell',
#  'Blondelle',
#  'Blondie',
#  'Blondy',
#  'Blythe',
#  'Bo',
#  'Bobbette',
#  'Bobbi',
#  'Bobbie',
#  'Bobby',
#  'Bobette',
#  'Bobina',
#  'Bobine',
#  'Bobinette',
#  'Bonita',
#  'Bonnee',
#  'Bonni',
#  'Bonnie',
#  'Bonny',
#  'Brana',
#  'Brandais',
#  'Brande',
#  'Brandea',
#  'Brandi',
#  'Brandice',
#  'Brandie',
#  'Brandise',
#  'Brandy',
#  'Brea',
#  'Breanne',
#  'Brear',
#  'Bree',
#  'Breena',
#  'Bren',
#  'Brena',
#  'Brenda',
#  'Brenn',
#  'Brenna',
#  'Brett',
#  'Bria',
#  'Briana',
#  'Brianna',
#  'Brianne',
#  'Bride',
#  'Bridget',
#  'Bridgett',
#  'Bridgette',
#  'Bridie',
#  'Brier',
#  'Brietta',
#  'Brigid',
#  'Brigida',
#  'Brigit',
#  'Brigitta',
#  'Brigitte',
#  'Brina',
#  'Briney',
#  'Briny',
#  'Brit',
#  'Brita',
#  'Britaney',
#  'Britani',
#  'Briteny',
#  'Britney',
#  'Britni',
#  'Britt',
#  'Britta',
#  'Brittan',
#  'Brittany',
#  'Britte',
#  'Brittney',
#  'Brook',
#  'Brooke',
#  'Brooks',
#  'Brunella',
#  'Brunhilda',
#  'Brunhilde',
#  'Bryana',
#  'Bryn',
#  'Bryna',
#  'Brynn',
#  'Brynna',
#  'Brynne',
#  'Buffy',
#  'Bunni',
#  'Bunnie',
#  'Bunny',
#  'Burta',
#  'Cabrina',
#  'Cacilia',
#  'Cacilie',
#  'Caitlin',
#  'Caitrin',
#  'Cal',
#  'Calida',
#  'Calla',
#  'Calley',
#  'Calli',
#  'Callida',
#  'Callie',
#  'Cally',
#  'Calypso',
#  'Cam',
#  'Camala',
#  'Camel',
#  'Camella',
#  'Camellia',
#  'Cameo',
#  'Cami',
#  'Camila',
#  'Camile',
#  'Camilla',
#  'Camille',
#  'Cammi',
#  'Cammie',
#  'Cammy',
#  'Canada',
#  'Candace',
#  'Candi',
#  'Candice',
#  'Candida',
#  'Candide',
#  'Candie',
#  'Candis',
#  'Candra',
#  'Candy',
#  'Cappella',
#  'Caprice',
#  'Cara',
#  'Caralie',
#  'Caren',
#  'Carena',
#  'Caresa',
#  'Caressa',
#  'Caresse',
#  'Carey',
#  'Cari',
#  'Caria',
#  'Carie',
#  'Caril',
#  'Carilyn',
#  'Carin',
#  'Carina',
#  'Carine',
#  'Cariotta',
#  'Carissa',
#  'Carita',
#  'Caritta',
#  'Carla',
#  'Carlee',
#  'Carleen',
#  'Carlen',
#  'Carlena',
#  'Carlene',
#  'Carley',
#  'Carli',
#  'Carlie',
#  'Carlin',
#  'Carlina',
#  'Carline',
#  'Carlisle',
#  'Carlita',
#  'Carlota',
#  'Carlotta',
#  'Carly',
#  'Carlye',
#  'Carlyn',
#  'Carlynn',
#  'Carlynne',
#  'Carma',
#  'Carmel',
#  'Carmela',
#  'Carmelia',
#  'Carmelina',
#  'Carmelita',
#  'Carmella',
#  'Carmelle',
#  'Carmen',
#  'Carmina',
#  'Carmine',
#  'Carmita',
#  'Carmon',
#  'Caro',
#  'Carol',
#  'Carol-Jean',
#  'Carola',
#  'Carolan',
#  'Carolann',
#  'Carole',
#  'Carolee',
#  'Caroleen',
#  'Carolie',
#  'Carolin',
#  'Carolina',
#  'Caroline',
#  'Caroljean',
#  'Carolyn',
#  'Carolyne',
#  'Carolynn',
#  'Caron',
#  'Carree',
#  'Carri',
#  'Carrie',
#  'Carrissa',
#  'Carrol',
#  'Carroll',
#  'Carry',
#  'Cary',
#  'Caryl',
#  'Caryn',
#  'Casandra',
#  'Casey',
#  'Casi',
#  'Casia',
#  'Casie',
#  'Cass',
#  'Cassandra',
#  'Cassandre',
#  'Cassandry',
#  'Cassaundra',
#  'Cassey',
#  'Cassi',
#  'Cassie',
#  'Cassondra',
#  'Cassy',
#  'Cat',
#  'Catarina',
#  'Cate',
#  'Caterina',
#  'Catha',
#  'Catharina',
#  'Catharine',
#  'Cathe',
#  'Cathee',
#  'Catherin',
#  'Catherina',
#  'Catherine',
#  'Cathi',
#  'Cathie',
#  'Cathleen',
#  'Cathlene',
#  'Cathrin',
#  'Cathrine',
#  'Cathryn',
#  'Cathy',
#  'Cathyleen',
#  'Cati',
#  'Catie',
#  'Catina',
#  'Catlaina',
#  'Catlee',
#  'Catlin',
#  'Catrina',
#  'Catriona',
#  'Caty',
#  'Cayla',
#  'Cecelia',
#  'Cecil',
#  'Cecile',
#  'Ceciley',
#  'Cecilia',
#  'Cecilla',
#  'Cecily',
#  'Ceil',
#  'Cele',
#  'Celene',
#  'Celesta',
#  'Celeste',
#  'Celestia',
#  'Celestina',
#  'Celestine',
#  'Celestyn',
#  'Celestyna',
#  'Celia',
#  'Celie',
#  'Celina',
#  'Celinda',
#  'Celine',
#  'Celinka',
#  'Celisse',
#  'Celle',
#  'Cesya',
#  'Chad',
#  'Chanda',
#  'Chandal',
#  'Chandra',
#  'Channa',
#  'Chantal',
#  'Chantalle',
#  'Charil',
#  'Charin',
#  'Charis',
#  'Charissa',
#  'Charisse',
#  'Charita',
#  'Charity',
#  'Charla',
#  'Charlean',
#  'Charleen',
#  'Charlena',
#  'Charlene',
#  'Charline',
#  'Charlot',
#  'Charlott',
#  'Charlotta',
#  'Charlotte',
#  'Charmain',
#  'Charmaine',
#  'Charmane',
#  'Charmian',
#  'Charmine',
#  'Charmion',
#  'Charo',
#  'Charyl',
#  'Chastity',
#  'Chelsae',
#  'Chelsea',
#  'Chelsey',
#  'Chelsie',
#  'Chelsy',
#  'Cher',
#  'Chere',
#  'Cherey',
#  'Cheri',
#  'Cherianne',
#  'Cherice',
#  'Cherida',
#  'Cherie',
#  'Cherilyn',
#  'Cherilynn',
#  'Cherin',
#  'Cherise',
#  'Cherish',
#  'Cherlyn',
#  'Cherri',
#  'Cherrita',
#  'Cherry',
#  'Chery',
#  'Cherye',
#  'Cheryl',
#  'Cheslie',
#  'Chiarra',
#  'Chickie',
#  'Chicky',
#  'Chiquita',
#  'Chloe',
#  'Chloette',
#  'Chloris',
#  'Chris',
#  'Chriss',
#  'Chrissa',
#  'Chrissie',
#  'Chrissy',
#  'Christa',
#  'Christabel',
#  'Christabella',
#  'Christabelle',
#  'Christal',
#  'Christalle',
#  'Christan',
#  'Christean',
#  'Christel',
#  'Christen',
#  'Christi',
#  'Christian',
#  'Christiana',
#  'Christiane',
#  'Christie',
#  'Christin',
#  'Christina',
#  'Christine',
#  'Christy',
#  'Christyna',
#  'Chrysa',
#  'Chrysler',
#  'Chrystal',
#  'Chryste',
#  'Chrystel',
#  'Ciara',
#  'Cicely',
#  'Cicily',
#  'Ciel',
#  'Cilka',
#  'Cinda',
#  'Cindee',
#  'Cindelyn',
#  'Cinderella',
#  'Cindi',
#  'Cindie',
#  'Cindra',
#  'Cindy',
#  'Cinnamon',
#  'Cissie',
#  'Cissy',
#  'Clair',
#  'Claire',
#  'Clara',
#  'Clarabelle',
#  'Clare',
#  ...]
